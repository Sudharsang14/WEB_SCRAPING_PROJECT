# %%
# Import BeautifulSoup for parsing HTML
from bs4 import BeautifulSoup

# Import requests to send HTTP requests
import requests

# %%
# URL of the website to scrape
url="https://www.ipl.com/cricket/news/ipl-2025-schedule-full-list-of-matches-fixtures-dates-venues-and-timings/"
# Send GET request to the website
page=requests.get(url)

# %%
#BeautifulSoup
soup=BeautifulSoup(page.text,'html')

# %%
# Find all tables in the webpage and select the first table
box=soup.find_all('table')[0]
box
# Out:
# <table><thead><tr><th><strong>Details</strong></th> <th><strong>Information</strong></th></tr> </thead> <tbody><tr><td><strong>Dates</strong></td> <td>22 March – 25 May 2025</td></tr> <tr><td><strong>Administrator(s)</strong></td> <td>Board of Control for Cricket in India (BCCI)</td></tr> <tr><td><strong>Format</strong></td> <td>T20</td></tr> <tr><td><strong>Tournament Format(s)</strong></td> <td>Group stage and playoffs</td></tr> <tr><td><b>Teams</b></td> <td>10</td></tr> <tr><td><strong>Matches</strong></td> <td>74</td></tr> <tr><td><strong>Official Website</strong></td> <td><a href="https://www.iplt20.com/">iplt20.com</a></td></tr></tbody></table>

# %%
initial= box.find_all('th')
below=[o.text.strip() for o in initial]
below
# Out:
# ['Details', 'Information']

# %%
# Import pandas to store scraped data in DataFrame
import pandas as pd
# Create an empty DataFrame with column names
df1=pd.DataFrame(columns=below)
df1
# Out:
# Empty DataFrame
# Columns: [Details, Information]
# Index: []

# %%
# Extract data from table body
for tbody in box.find_all('tbody'):        # Loop through each <tbody>
    for tr in tbody.find_all('tr'):        # Loop through each row <tr>
        cols=[td.text.strip() for td in tr.find_all('td')]
        length=len(df1)                    # Get current length of DataFrame (next row index)
        df1.loc[length]=cols               # Insert row into DataFrame

# %%
df1.to_csv()                             #save dataframe to csv
df1
# Out:
#                 Details                                   Information
# 0                 Dates                        22 March – 25 May 2025
# 1      Administrator(s)  Board of Control for Cricket in India (BCCI)
# 2                Format                                           T20
# 3  Tournament Format(s)                      Group stage and playoffs
# 4                 Teams                                            10
# 5               Matches                                            74
# 6      Official Website                                    iplt20.com

# %%
# Find all tables in the webpage and select the second table
table=soup.find_all('table')[1]
table
# Out:
# <table><thead><tr><th>Match</th> <th>Date</th> <th>Fixture</th> <th>Venue</th> <th>Time (IST)</th> <th>Day</th></tr> </thead> <tbody><tr><td>1</td> <td>March 22, 2025</td> <td>Kolkata Knight Riders vs Royal Challengers Bengaluru</td> <td>Kolkata</td> <td>7:30 PM</td> <td>Saturday</td></tr> <tr><td>2</td> <td>March 23, 2025</td> <td>Sunrisers Hyderabad vs Rajasthan Royals</td> <td>Hyderabad</td> <td>3:30 PM</td> <td>Sunday</td></tr> <tr><td>3</td> <td>March 23, 2025</td> <td>Chennai Super Kings vs Mumbai Indians</td> <td>Chennai</td> <td>7:30 PM</td> <td>Sunday</td></tr> <tr><td>4</td> <td>March 24, 2025</td> <td>Delhi Capitals
</td></tr> <tr><td>21</td> <td>April 7, 2025</td> <td>Mumbai Indians vs Royal Challengers Bengaluru</td> <td>Mumbai</td> <td>7:30 PM</td> <td>Monday</td></tr> <tr><td>22</td> <td>April 8, 2025</td> <td>Punjab Kings vs Chennai Super Kings</td> <td>New Chandigarh</td> <td>7:30 PM</td> <td>Tuesday</td></tr> <tr><td>23</td> <td>April 9, 2025</td> <td>Gujarat Titans vs Rajasthan Royals</td> <td>Ahmedabad</td> <td>7:30 PM</td> <td>Wednesday</td></tr> <tr><td>24</td> <td>April 10, 2025</td> <td>Royal Challengers Bengaluru vs Delhi Capitals</td> <td>Bengaluru</td> <td>7:30 PM</td> <td>Thursday</td></tr> <tr><td>25</td> <td>April 11, 2025</td> <td>Chennai Super Kings vs Kolkata Knight Riders</td> <td>Chennai</td> <td>7:30 PM</td> <td>Friday</td></tr> <tr><td>26</td> <td>April 12, 2025</td> <td>Lucknow Super Giants vs Gujarat Titans</td> <td>Lucknow</td> <td>3:30 PM</td> <td>Saturday</td></tr> <tr><td>27</td> <td>April 12, 2025</td> <td>Sunrisers H ...

# %%
title= table.find_all('th')
values=[i.text.strip() for i in title]
values
# Out:
# ['Match', 'Date', 'Fixture', 'Venue', 'Time (IST)', 'Day']

# %%
import pandas as pd
df2=pd.DataFrame(columns=values)
df2
# Out:
# Empty DataFrame
# Columns: [Match, Date, Fixture, Venue, Time (IST), Day]
# Index: []

# %%
for tbody in table.find_all('tbody'):
    for tr in tbody.find_all('tr'):
        cols=[td.text.strip() for td in tr.find_all('td')]
        length=len(df2)
        df2.loc[length]=cols

# %%
df2
# Out:
#    Match            Date                                            Fixture  \
# 0      1  March 22, 2025  Kolkata Knight Riders vs Royal Challengers Ben...
# 1      2  March 23, 2025            Sunrisers Hyderabad vs Rajasthan Royals
# 2      3  March 23, 2025              Chennai Super Kings vs Mumbai Indians
# 3      4  March 24, 2025             Delhi Capitals vs Lucknow Super Giants
# 4      5  March 25, 2025                     Gujarat Titans vs Punjab Kings
# ..   ...             ...                                                ...
# 69    70    May 18, 2025        Lucknow Super Giants vs Sunrisers Hyderabad
# 70    71    May 20, 2025                                        Qualifier 1
# 71    72    May 21, 2025                                         Eliminator
# 72    73    May 23, 2025                                        Qualifier 2
# 73    74    May 25, 2025                                              Final
#
#             Venue Time (IST)        Day
# 0         Kolkata    7:30 PM   Saturday
# 1       Hyderabad    3:30 PM     Sunday
# 2         Chennai    7:30 PM     Sunday
# 3   Visakhapatnam    7:30 PM     Monday
# 4       Ahmedabad    7:30 PM    Tuesday
# ..            ...        ...        ...
# 69        Lucknow    7:30 PM     Sunday
# 70      Hyderabad    7:30 PM    Tuesday
# 71      Hyderabad    7:30 PM  Wednesday
# 72        Kolkata    7:30 PM     Friday
# 73        Kolkata    7:30 PM     Sunday
#
# [74 rows x 6 columns]
